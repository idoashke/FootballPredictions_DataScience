# %%
# %run Machine_Learning.ipynb
# Out:
# <style  type="text/css" >
#     #T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519f th {
#           text-align: left;
#     }#T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519frow0_col0,#T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519frow1_col0,#T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519frow2_col0,#T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519frow3_col0,#T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519frow4_col0{
#             text-align:  left;
#         }</style><table id="T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Competition</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_787dc7fd_e3d4_11eb_8dbf_eccf54a3519frow0_col0" class="data row0 col0" >Bundesliga</td>
#             </tr>
#             <tr>
# ...

# %%
# %run Date_Picker.ipynb
# Out:
# Please choose the date of the match you want to predict and then press "Lets Go!" button
# DatePicker(value=None, description='Pick a Date')
# Button(button_style='info', description=' Lets Go!', icon='check', style=ButtonStyle(), tooltip='Click me')
# The chosen date is:  2021-07-17
# Stored 'chosen_date' (str)
# Stored variables and their in-db values:
# chosen_date              -> '2021-07-17'
# chosen_model             -> LogisticRegression(random_state=0, solver='libline

# %%
# %run Match_Predict.ipynb
# Out:
# chosen_date is:  2021-07-17
# <style  type="text/css" >
#     #T_ffa4cb40_e3d5_11eb_9e1b_eccf54a3519f th {
#           text-align: left;
# ...
